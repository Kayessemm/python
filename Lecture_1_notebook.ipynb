# %%
5 + 6 # whole numbers
# Out:
# 11

# %%
10 // 3 # integer division
# Out:
# 3

# %%
10 % 3 # Modulo operator
# Out:
# 1

# %%
10 ** 3 # Exponentiation operator
# Out:
# 1000

# %%
50 > 25 # boolean operator
# Out:
# True

# %%
-15 >= -14.99
# Out:
# False

# %%
20 == 20
# Out:
# True

# %%
20 != 20
# Out:
# False

# %%
# variable names can have letters, numbers, and underscores, but cannot start with a number; they are case-sensitive

# %%
degrees_celsius = 25

# %%
degrees_celsius
# Out:
# 25

# %%
degrees_fahrenheit = (9/5) * degrees_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_celcius = 0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_celsius = degrees_celsius + 10

# %%
degrees_celsius
# Out:
# 35

# %%
a = 1

# %%
a
# Out:
# 1

# %%
b = a

# %%
b
# Out:
# 1

# %%
a = 2

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
no_of_weeks = no_of_weeks + 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 no_of_weeks = no_of_weeks + 10
#
# NameError: name 'no_of_weeks' is not defined

# %%
no_of_weeks = 4

# %%
no_of_weeks = no_of_weeks + 10

# %%
no_of_weeks += 10

# %%
no_of_weeks
# Out:
# 24

# %%
# 37 does the same thing as 36, but with fewer characters

# %%
degrees_celsius = 0
degrees_celsius
# Out:
# 0

# %%
degrees_celsius -= 10

# %%
degrees_celsius
# Out:
# -10

# %%
import numpy as np

# %%
12 = x
# Out:
#   Cell In[44], line 1
#     12 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
12 -
# Out:
#   Cell In[45], line 1
#     12 -
#         ^
# SyntaxError: invalid syntax

# %%
my variable + 1
# Out:
#   Cell In[46], line 1
#     my variable + 1
#        ^
# SyntaxError: invalid syntax

# %%
x = 12

# %%
x + 7
# Out:
# 19

# %%
# This is a comment

# %%
y = x + 7
y + x
# Out:
# 31

# %%
# white space: a space on either side of an operand

# %%
# Split code across multiple lines by wrapping it in parentheses

# %%
(10000000 + 
5000000)
# Out:
# 15000000

# %%
# comments:
# explain your code and plan fture work in plain language
# toggle lines of code on/off during debugging

# %%
Kaylie_vacations = 30
# Kaylie_vacations = Kaylie_vacations + 10
Kaylie_vacations = Kaylie_vacations -1

# %%
Kaylie_vacations
# Out:
# 39

# %%
# clear and consistent variable names
# they should be descriptive

# %%
# function is a named block of code that performs a specific task; 
# it can take zero or more input values and one or more return values

# %%
print(42)
# Out:
# 42

# %%
type (42)
# Out:
# int

# %%
abs(-43)
# Out:
# 43

# %%
int(3.99)
# Out:
# 3

# %%
float(7)
# Out:
# 7.0

# %%
round(2/3)
# Out:
# 1

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
round(2/3, 4)
# Out:
# 0.6667

# %%
print(round(abs(-16) * 1.5))
# Out:
# 24

# %%
# Defining a function

def c_to_f(degrees_c):
    degrees_f = (9 / 5) * degrees_c + 32
    return degrees_f

# %%
c_to_f(100)
# Out:
# 212.0

# %%
# parameters are placeholders for the values you provide when calling the function
# they are local variables within the function, only accessible in the code
# the argument is the actual value passed to the function when called
# the argument corresponds to parameters for the function to work on/return

# %%
c_to_f(-11)
# Out:
# 12.2

# %%
degrees_c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 degrees_c
#
# NameError: name 'degrees_c' is not defined

# %%
def divide(dividend, divisor):
    output = dividend / divisor
    return output

# %%
divide(100, 5)
# Out:
# 20.0

# %%
def calc_sales_tax(price, tax_rate=0.13):
    tax_amount = price * tax_rate
    return tax_amount

# %%
calc_sales_tax(15)
# Out:
# 1.9500000000000002

# %%
calc_sales_tax(5, 0.08)
# Out:
# 0.4

# %%
def calc_total_bill(price, tax_rate=0.13, tip_rate=0.15):
    tax_amt = price * tax_rate
    tip_amt = price * tip_rate
    return price + tax_amt + tip_amt

# %%
calc_total_bill(100)
# Out:
# 128.0

# %%
# Want to tip 18% using keyword argument:
calc_total_bill(100, tip_rate=0.18)
# Out:
# 131.0

# %%
# docstrings allow you to write descriptions of your functions.

def c_to_f(degrees_c):
    """Convert degrees from Celsius to Fahrenheit."""
    return ((9 / 5) * degrees_c + 32)

# %%
help(c_to_f)
# Out:
# Help on function c_to_f in module __main__:
#
# c_to_f(degrees_c)
#     Convert degrees from Celsius to Fahrenheit.
